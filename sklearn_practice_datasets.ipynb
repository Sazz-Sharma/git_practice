# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print("Imported")
data_frame=pd.read_csv("BTC-USD.csv")
x_axis=data_frame["Open"]
y_axis=data_frame["Close"]
X_train,X_test,Y_train,Y_test=train_test_split(x_axis,y_axis)
# X_train,X_test=train_test_split(x_axis)
# Y_train,Y_test=train_test_split(y_axis)
plt.scatter(X_test,Y_test,c="#00ff00")
plt.scatter(X_train,Y_train,c="#ff0000")
plt.xlabel("Open Price")
plt.ylabel("Close price")
plt.legend(["Test","Train"])

print(reg.score(X_test.values.reshape(-1,1),Y_test))
# Out:
# Imported
# 0.9571653864752576

# %%
arr1=np.arange(1,16)
arr2=np.arange(5,76,5)
arr1_train,arr1_test,arr2_train,arr2_test=train_test_split(arr1,arr2)
# print(arr1.reshape(-1,1))
regressor=LinearRegression().fit(arr1_train.reshape(-1,1),arr2_train)
plt.scatter(arr1,arr2)
regressor.score(arr1_test.reshape(-1,1),arr2_test)
# Out:
# 1.0
